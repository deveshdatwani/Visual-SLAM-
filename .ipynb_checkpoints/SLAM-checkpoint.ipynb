# %%
import sys
import cv2
import numpy as np
from math import * 
import os
from matplotlib import pyplot as plt

# %%
# %run Match.ipynb
# %run RANSAC.ipynb

# %%
class structureFromMotion(Match, RANSAC):
    
    def __init__(self, numberOfImages=None):
        self.numberOfImages = numberOfImages
        self.baseAddress = os.getcwd() + "/P3Data/"
    
    def showImage(self, image):
        plt.imshow(image)
        return None
    
    def matchTwoImages(self, image1, image2):
        matches = self.featureMatching(image1, image1)
        return matches

# %%
structure = structureFromMotion()

# %%
imageFile = "1.png"
image2File = "2.png"
imageAddress = structure.baseAddress + imageFile
image2Address = structure.baseAddress + image2File
image1 = cv2.imread(imageAddress, 0)
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.imread(image2Address, 0)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %%
keyPoints1, descriptorsImage1 = structure.featureExtraction(image1)
keyPoints2, descriptorsImage2 = structure.featureExtraction(image2)

# %%
matches = structure.featureMatching(descriptorsImage1, descriptorsImage2)

# %%
F = structure.ransacAlgorithm(matches, np.asarray(keyPoints1), np.asarray(keyPoints2))
# Out:
# (< cv2.KeyPoint 0x7fb8a25ff3c0>, < cv2.KeyPoint 0x7fb8a25ff450>, < cv2.KeyPoint 0x7fb8dc795930>, < cv2.KeyPoint 0x7fb8dc795720>, < cv2.KeyPoint 0x7fb8a25f1f60>, < cv2.KeyPoint 0x7fb8dc79a9f0>, < cv2.KeyPoint 0x7fb8dc79af30>, < cv2.KeyPoint 0x7fb8dc79a120>, < cv2.KeyPoint 0x7fb8dc79a840>, < cv2.KeyPoint 0x7fb8dc79a990>, < cv2.KeyPoint 0x7fb8dc78ab40>, < cv2.KeyPoint 0x7fb8dc78a180>, < cv2.KeyPoint 0x7fb8dc78aa80>, < cv2.KeyPoint 0x7fb8dc78ab70>, < cv2.KeyPoint 0x7fb8dc78a0c0>, < cv2.KeyPoint 0x7fb8dc78afc0>, < cv2.KeyPoint 0x7fb8dc78a660>, < cv2.KeyPoint 0x7fb8dc78ab10>, < cv2.KeyPoint 0x7fb8a23ee990>, < cv2.KeyPoint 0x7fb8a23ee720>, < cv2.KeyPoint 0x7fb8a23eed80>, < cv2.KeyPoint 0x7fb8a23ee750>, < cv2.KeyPoint 0x7fb8a23eea80>, < cv2.KeyPoint 0x7fb8a23ee900>, < cv2.KeyPoint 0x7fb8a23eec30>, < cv2.KeyPoint 0x7fb8a23ee360>, < cv2.KeyPoint 0x7fb8a23ee810>, < cv2.KeyPoint 0x7fb8a23ee2d0>, < cv2.KeyPoint 0x7fb8a23ee840>, < cv2.KeyPoint 0x7fb8a23eecf0>, < cv2.KeyPoint 0x7fb8a23eeab0>, < cv2.KeyPoint 0x7fb8a23ee330>, < cv2.KeyPoint 0x7fb8a23ee780>, < cv2.KeyPoint 0x7fb8a23eee70>, < cv2.KeyPoint 0x7fb8a23ee7b0>, < cv2.KeyP
KeyPoint 0x7fb8a23a43f0>, < cv2.KeyPoint 0x7fb8a23a4240>, < cv2.KeyPoint 0x7fb8a23a4180>, < cv2.KeyPoint 0x7fb8a23a41e0>, < cv2.KeyPoint 0x7fb8a23a41b0>, < cv2.KeyPoint 0x7fb8a23a42a0>, < cv2.KeyPoint 0x7fb8a23a4660>, < cv2.KeyPoint 0x7fb8a23a4630>, < cv2.KeyPoint 0x7fb8a23a4690>, < cv2.KeyPoint 0x7fb8a23a47e0>, < cv2.KeyPoint 0x7fb8a23a4720>, < cv2.KeyPoint 0x7fb8a23a4810>, < cv2.KeyPoint 0x7fb8a23a47b0>, < cv2.KeyPoint 0x7fb8a23a4300>, < cv2.KeyPoint 0x7fb8a23a4210>, < cv2.KeyPoint 0x7fb8a23a4990>, < cv2.KeyPoint 0x7fb8a23a4750>, < cv2.KeyPoint 0x7fb8a23a4930>, < cv2.KeyPoint 0x7fb8a23a49c0>, < cv2.KeyPoint 0x7fb8a23a4960>, < cv2.KeyPoint 0x7fb8a23a4270>, < cv2.KeyPoint 0x7fb8a23a4a20>, < cv2.KeyPoint 0x7fb8a23a4480>, < cv2.KeyPoint 0x7fb8a23a4a50>, < cv2.KeyPoint 0x7fb8a23a46f0>, < cv2.KeyPoint 0x7fb8a23a4ab0>, < cv2.KeyPoint 0x7fb8a23a4a80>, < cv2.KeyPoint 0x7fb8a23a4b40>, < cv2.KeyPoint 0x7fb8a23a4b70>, < cv2.KeyPoint 0x7fb8a23a4ba0>, < cv2.KeyPoint 0x7fb8a23a4bd0>, < cv2.KeyPoint 0x7fb8a23a4c00>, < cv2.KeyPoint 0x7fb8a23a4c30>, < cv2.KeyPoint 0x7fb8a23a4c60>, < cv2.KeyPoint 0x7fb8a23a4ae0>, ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-65fbe4615b86> in <module>
# ----> 1 F = structure.ransacAlgorithm(matches, np.asarray(keyPoints1), np.asarray(keyPoints2))
#
# <ipython-input-2-07e348a5d9fa> in ransacAlgorithm(self, matches, kepPoints1, keyPoints2, threshold)
#      17     def ransacAlgorithm(self, matches, kepPoints1, keyPoints2, threshold=0.005, ):
#      18         randomKeyPoints = self.chooseKeyPoints(matches)
# ---> 19         fundamentalMatrix = self.findFMatrix(randomKeyPoints, keyPoints1, keyPoints2)
#      20         return fundamentalMatrix
#
# <ipython-input-2-07e348a5d9fa> in findFMatrix(self, randomKeyPoints, keyPoints1, keyPoints2)
#      10     def findFMatrix(self, randomKeyPoints, keyPoints1, keyPoints2):
#      11         print(keyPoints1)
# ---> 12         eightKeyPointsImage1 = keyPoints1[randomKeyPoints]
#      13         eightKeyPointsImage2 = keyPoints2[randomKeyPoints]
#      14         fundamentalMatrix = cv2.findFundamentalMat(eightKeyPointsImage1, eightKeyPointsImage2, cv2.FM_LMEDS)
#
# TypeError: only integer scalar arrays can be converted to a scalar index
